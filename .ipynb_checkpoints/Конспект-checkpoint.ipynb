# %%
import numpy as np

# %%
A = np.array([1,2,3])
B = np.array([2,3,4])
print(A+B, A*B)
# Out:
# [3 5 7] [ 2  6 12]

# %% [markdown]
# Нампай масиви швидші для одного типу даних, та якщо можна векторизувати масив
# Звичайний список швидший для видалення останньго елемента
# Список для перетворення в масив має бути однорідний інакше тип буде object

# %% [markdown]
# часто виникає потреба створити масив за формою як попередній але з нулів.(або інших елементів)
# ![image.png](attachment:a88535dc-e7be-45ee-a13c-71a7288bc7c5.png)

# %%
a = np.zeros(3, float)
c = np.zeros_like(a, int)
c
# Out:
# array([0, 0, 0])

# %% [markdown]
# Для монотонних послідовностей.
# ![image.png](attachment:225ed177-b4b7-488a-9034-102d4c9d9fa6.png)![image.png](attachment:c811cef1-2619-4e06-85bb-3c9bc15b4f9b.png)

# %%
a = np.arange(3,6,0.1)
a
# Out:
# array([3. , 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8, 3.9, 4. , 4.1, 4.2,
#        4.3, 4.4, 4.5, 4.6, 4.7, 4.8, 4.9, 5. , 5.1, 5.2, 5.3, 5.4, 5.5,
#        5.6, 5.7, 5.8, 5.9])

# %%
a = np.arange(1,6)
print(a[2:4], a[-2:], a[::2], a[[1,2,3]])
# Out:
# [3 4] [4 5] [1 3 5] [2 3 4]

# %%
a = [1,2,3]
b = a #не копія а просто інше імя
print(b)
c = a[:] # copy
a = np.arange(1,5)
b = a # no copy
d = a.copy()
c = a[:] # no copy

print(b)
# Out:
# [1, 2, 3]
# [1 2 3 4]

# %%
#Булеве індексування 
a = np.arange(1,10)
a[(a >= 5) & (a>=6)] = 0
print(a)
print(np.all(a>5), a[a>5], np.any(a> 5), b)
# Out:
# [1 2 3 4 5 0 0 0 0]
# False [] False 0

# %% [markdown]
# ![image.png](attachment:c5e8ef18-b386-4e94-aa5a-c411e9260010.png)![image.png](attachment:6b5ced2b-944f-4e05-900b-36423968898a.png)
# np.where повертає кортеж

# %%
a = np.arange(1,10)
print(np.where(a>5), np.nonzero(a>5))
print(np.clip(a,2,5))
np.where(a >=5, 1, 0)
# Out:
# (array([5, 6, 7, 8]),) (array([5, 6, 7, 8]),)
# [2 2 3 4 5 5 5 5 5]
# array([0, 0, 0, 0, 1, 1, 1, 1, 1])

# %% [markdown]
# ### Векторні операції
